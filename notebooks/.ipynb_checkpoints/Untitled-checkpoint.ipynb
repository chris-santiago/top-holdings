# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import ColorBar, ColumnDataSource
from bokeh.transform import factor_cmap
from bokeh.palettes import brewer, d3
from sklearn.preprocessing import MinMaxScaler

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
def make_plot(data, cap):
    data = data.copy()
    data = data[data['market_cap'] == cap]
    sectors = data['sector'].unique()
    sc = MinMaxScaler((10, 100))
    data['scaled_value'] = sc.fit_transform(data['value'].values.reshape(-1, 1))
    
    tooltips = [
        ('Company', '@shortName'),
        ('Ticker', '@ticker'),
        ('Owned ($000s)', '@value{0,0}'),
        ('Industry', '@industry'),
    ]
    p = figure(plot_width=800, plot_height=800, tooltips=tooltips, title=f'Top 50 {cap.title()}-Cap Institutional Holdings', x_axis_label='Principal Component 1',
              y_axis_label='Principal Component 2')
    source = ColumnDataSource(data=data)
    cmap = factor_cmap('sector', palette=d3['Category20'][len(sectors)], factors=sectors)
    p.circle('pc1', 'pc2', source=source, size='scaled_value', color=cmap, alpha=0.7, legend_group='sector')
    p.legend.location = "top_left"
    show(p)

# %%
DATA = pd.read_csv('../data.csv').sort_values('value', ascending=False)
DATA.head()
# Out:
#     ticker   report_pd              shortName                  sector  \
# 374   MSFT  2020-12-31  Microsoft Corporation              Technology
# 3     AAPL  2020-12-31             Apple Inc.              Technology
# 215     FB  2020-12-31         Facebook, Inc.  Communication Services
# 251  GOOGL  2020-12-31          Alphabet Inc.  Communication Services
# 34    AMZN  2020-12-31       Amazon.com, Inc.       Consumer Cyclical
#
#                            industry         value market_cap        pc1  \
# 374         Software—Infrastructure  1.161816e+09       mega  11.403084
# 3              Consumer Electronics  8.691445e+08       mega  21.070558
# 215  Internet Content & Information  7.093901e+08       mega   1.267449
# 251  Internet Content & Information  6.976856e+08       mega -14.609293
# 34                  Internet Retail  5.773960e+08       mega -14.148967
#
#            pc2
# 374 -14.298780
# 3    -7.521290
# 215  -9.624355
# 251  -5.808565
# 34   -3.995375

# %%
for cap in DATA['market_cap'].unique():
    output_file(f'{cap}-cap.html')
    make_plot(DATA, cap)
# Out:
#   <div class="bk-root" id="f0fe0c67-34df-4cbb-9322-e172b32d063f" data-root-id="1002"></div>
#   <div class="bk-root" id="27051368-3fb9-4a01-b5c6-4c397800f756" data-root-id="1182"></div>
#   <div class="bk-root" id="940d9f97-cd4b-4d87-a2ca-e5626fe589fa" data-root-id="1390"></div>
#   <div class="bk-root" id="8d4e7b80-77dc-4c42-86af-9107d5b8e0a5" data-root-id="1605"></div>
#   <div class="bk-root" id="3172e56c-9f4b-4ae1-a5e8-8d7b7ac5b578" data-root-id="1826"></div>
